# %%
import yfinance as yf
import pandas as pd

from datetime import datetime, timedelta, date

# %%
list_code = ['1A1.SI',
 '1AZ.SI',
 '1B1.SI',
 '1D0.SI',
 '1E3.SI',
 '1F2.SI',
 '1J4.SI',
 '1J5.SI',
 '1J7.SI',
 '1MZ.SI',
 '1R6.SI',
 '40T.SI',
 '41B.SI',
 '41O.SI',
 '42E.SI',
 '42R.SI',
 '500.SI',
 '508.SI',
 '533.SI',
 '53W.SI',
 '543.SI',
 '544.SI',
 '558.SI',
 '564.SI',
 '5CF.SI',
 '5DD.SI',
 '5DP.SI',
 '5DS.SI',
 '5E2.SI',
 '5G3.SI',
 '5GD.SI',
 '5IC.SI',
 '5JK.SI',
 '5JS.SI',
 '5MD.SI',
 '5ML.SI',
 '5MZ.SI',
 '5SR.SI',
 '5SY.SI',
 '5TP.SI',
 '5VJ.SI',
 '5VS.SI',
 '5WJ.SI',
 '600.SI',
 '8A8.SI',
 '8AZ.SI',
 '9A4U.SI',
 '9CI.SI',
 'A17U.SI',
 'A7RU.SI',
 'ACV.SI',
 'ADN.SI',
 'AGS.SI',
 'AIY.SI',
 'AJBU.SI',
 'AP4.SI',
 'AU8U.SI',
 'AVX.SI',
 'AW9U.SI',
 'AWC.SI',
 'AWG.SI',
 'AWI.SI',
 'AWK.SI',
 'AWV.SI',
 'AWX.SI',
 'AWZ.SI',
 'AYN.SI',
 'B28.SI',
 'B58.SI',
 'B61.SI',
 'B9S.SI',
 'BAI.SI',
 'BAZ.SI',
 'BBP.SI',
 'BBW.SI',
 'BCY.SI',
 'BDA.SI',
 'BDR.SI',
 'BEC.SI',
 'BEI.SI',
 'BEW.SI',
 'BEZ.SI',
 'BFK.SI',
 'BFU.SI',
 'BHU.SI',
 'BIX.SI',
 'BJZ.SI',
 'BKA.SI',
 'BKK.SI',
 'BKX.SI',
 'BLH.SI',
 'BLS.SI',
 'BMGU.SI',
 'BN2.SI',
 'BN4.SI',
 'BNE.SI',
 'BPF.SI',
 'BQD.SI',
 'BQF.SI',
 'BQM.SI',
 'BQP.SI',
 'BS6.SI',
 'BSL.SI',
 'BTE.SI',
 'BTG.SI',
 'BTJ.SI',
 'BTM.SI',
 'BTP.SI',
 'BTX.SI',
 'BTY.SI',
 'BUOU.SI',
 'BVQ.SI',
 'BWCU.SI',
 'BWM.SI',
 'C05.SI',
 'C07.SI',
 'C09.SI',
 'C2PU.SI',
 'C38U.SI',
 'C41.SI',
 'C52.SI',
 'C6L.SI',
 'C76.SI',
 'CC3.SI',
 'CHJ.SI',
 'CHZ.SI',
 'CJLU.SI',
 'CJN.SI',
 'CLN.SI',
 'CMOU.SI',
 'CRPU.SI',
 'CY6U.SI',
 'D01.SI',
 'D05.SI',
 'DCRU.SI',
 'DHLU.SI',
 'DM0.SI',
 'E28.SI',
 'E3B.SI',
 'E5H.SI',
 'EB5.SI',
 'EH5.SI',
 'EMI.SI',
 'ER0.SI',
 'F03.SI',
 'F17.SI',
 'F1E.SI',
 'F34.SI',
 'F99.SI',
 'F9D.SI',
 'G07.SI',
 'G0I.SI',
 'G13.SI',
 'G20.SI',
 'G50.SI',
 'G92.SI',
 'H02.SI',
 'H07.SI',
 'H12.SI',
 'H13.SI',
 'H15.SI',
 'H18.SI',
 'H22.SI',
 'H30.SI',
 'H78.SI',
 'HKB.SI',
 'HLS.SI',
 'HMN.SI',
 'HQU.SI',
 'I06.SI',
 'I07.SI',
 'ITS.SI',
 'J2T.SI',
 'J36.SI',
 'J69U.SI',
 'J85.SI',
 'JLB.SI',
 'JYEU.SI',
 'K03.SI',
 'K29.SI',
 'K6S.SI',
 'K71U.SI',
 'K75.SI',
 'KYB.SI',
 'L19.SI',
 'LCC.SI',
 'LJ3.SI',
 'LMS.SI',
 'LVR.SI',
 'M01.SI',
 'M04.SI',
 'M05.SI',
 'M14.SI',
 'M1GU.SI',
 'M44U.SI',
 'ME8U.SI',
 'MR7.SI',
 'MV4.SI',
 'MXNU.SI',
 'MZH.SI',
 'N02.SI',
 'N08.SI',
 'N0Z.SI',
 'N2IU.SI',
 'NC2.SI',
 'NEX.SI',
 'NIO.SI',
 'NPW.SI',
 'NS8U.SI',
 'NTDU.SI',
 'O10.SI',
 'O39.SI',
 'O5RU.SI',
 'O6Z.SI',
 'OAJ.SI',
 'ODBU.SI',
 'OTX.SI',
 'OU8.SI',
 'OV8.SI',
 'OYY.SI',
 'P15.SI',
 'P34.SI',
 'P40U.SI',
 'P52.SI',
 'P7VU.SI',
 'P8A.SI',
 'P8Z.SI',
 'P9D.SI',
 'PCT.SI',
 'Q01.SI',
 'Q0F.SI',
 'Q5T.SI',
 'QC7.SI',
 'QES.SI',
 'QNS.SI',
 'RE4.SI',
 'S07.SI',
 'S08.SI',
 'S19.SI',
 'S20.SI',
 'S23.SI',
 'S29.SI',
 'S2D.SI',
 'S35.SI',
 'S41.SI',
 'S44.SI',
 'S56.SI',
 'S58.SI',
 'S59.SI',
 'S61.SI',
 'S63.SI',
 'S68.SI',
 'S85.SI',
 'SEB.SI',
 'SET.SI',
 'SO7.SI',
 'STG.SI',
 'T12.SI',
 'T14.SI',
 'T15.SI',
 'T24.SI',
 'T55.SI',
 'T6I.SI',
 'T82U.SI',
 'TCU.SI',
 'TQ5.SI',
 'TS0U.SI',
 'TSH.SI',
 'U06.SI',
 'U10.SI',
 'U11.SI',
 'U13.SI',
 'U14.SI',
 'U77.SI',
 'U96.SI',
 'U9E.SI',
 'UD1U.SI',
 'URR.SI',
 'UZF.SI',
 'V03.SI',
 'V5Q.SI',
 'VC2.SI',
 'W05.SI',
 'WJP.SI',
 'WKS.SI',
 'X5N.SI',
 'XVG.SI',
 'XWA.SI',
 'XZL.SI',
 'Y03.SI',
 'Y92.SI',
 'YF8.SI',
 'YYN.SI',
 'Z25.SI',
 'Z74.SI',
 'Z77.SI',
 'ZB9.SI',
 'ZKX.SI',
 'ZXY.SI']

# %%
df_stock = pd.read_csv("Stock Screener Data 31 Aug 2-16-26.csv.csv")

df_stock["Yahoo_Code"] = df_stock["Code"] + ".SI"

list_stock = []

for index, row in df_stock.iterrows():
    list_stock.append(row["Yahoo_Code"])

elements_to_remove = ['M12.SI', 'PJX.SI', 'N33.SI']

new_list = [item for item in list_stock if item not in elements_to_remove]

# print(list_stock)


# data = yf.Ticker("D05.SI")

# print(dat.history(period='5d'))

response = yf.download(list_code, period='5d')

print(response.T)
# Out:
# C:\Users\john\AppData\Local\Temp\ipykernel_8836\1627233098.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   response = yf.download(list_code, period='5d')
# [*********************100%***********************]  299 of 299 completed
# Date             2025-08-25    2025-08-26    2025-08-27    2025-08-28  \
# Price  Ticker
# Close  1A1.SI  1.710000e-01  1.820000e-01  2.450000e-01  1.800000e-01
#        1AZ.SI  2.650000e-01  2.750000e-01  2.750000e-01  2.750000e-01
#        1B1.SI  3.300000e-01  3.300000e-01  3.300000e-01  3.250000e-01
#        1D0.SI  3.550000e-01  3.600000e-01  3.600000e-01  3.600000e-01
#        1E3.SI  2.332324e-01  2.332324e-01  2.282700e-01  2.300000e-01
# ...                     ...           ...           ...           ...
# Volume Z74.SI  3.203040e+07  3.721320e+07  2.402387e+07  2.549660e+07
#        Z77.SI  1.533900e+05  2.932100e+05  1.680900e+05  1.224000e+05
#        ZB9.SI  3.250000e+04           NaN  3.720000e+04           NaN
#        ZKX.SI           NaN  2.438000e+05  4.350000e+04  1.353000e+05
#        ZXY.SI  4.669000e+05  1.000000e+05  5.930000e+04  0.000000e+00
#
# Date             2025-08-29
# Price  Ticker
# Close  1A1.SI  1.800000e-01
#        1AZ.SI  2.800000e-01
#        1B1.SI  3.300000e-01
#        1D0.SI  3.650000e-01
#        1E3.SI  2.550000e-01
# ...                     ...
# Volume Z74.SI  1.605460e+07
#        Z77.SI  1.000000e+05
#        ZB9.SI           NaN
#        ZKX.SI  8.440000e+04
#        ZXY.SI  2.054000e+05
#
# [1495 rows x 5 columns]

# %%
df = response.T

# %%
today = datetime.today()
lastweek = today - timedelta(days=4)
today = lastweek.strftime('%Y-%m-%d')

# %%
filtered_df = df[df[today] > 0.2]

# %%
filtered_df.T
# Out:
# Price       Close                                                             \
# Ticker     1A1.SI 1AZ.SI 1B1.SI 1D0.SI    1E3.SI 1F2.SI 1J4.SI 1J5.SI 1J7.SI
# Date
# 2025-08-25  0.171  0.265  0.330  0.355  0.233232  0.365   0.26  0.320    0.2
# 2025-08-26  0.182  0.275  0.330  0.360  0.233232  0.380   0.26  0.325    0.2
# 2025-08-27  0.245  0.275  0.330  0.360  0.228270  0.375   0.25  0.330    0.2
# 2025-08-28  0.180  0.275  0.325  0.360  0.230000  0.365   0.25  0.340    0.2
# 2025-08-29  0.180  0.280  0.330  0.365  0.255000  0.375   0.25  0.340    0.2
#
# Price              ...     Volume                                   \
# Ticker     1MZ.SI  ...     XZL.SI   Y03.SI      Y92.SI      YF8.SI
# Date               ...
# 2025-08-25  0.765  ...  1156600.0   2900.0  14131600.0  11404000.0
# 2025-08-26  0.730  ...   254000.0      0.0  26466700.0  13453700.0
# 2025-08-27  0.725  ...   180000.0  10000.0   9129400.0   6873100.0
# 2025-08-28  0.710  ...   315300.0      0.0  13305000.0   8090800.0
# 2025-08-29  0.710  ...   650000.0   4700.0   5714400.0  12083500.0
#
# Price
# Ticker          Z25.SI      Z74.SI    Z77.SI   ZB9.SI    ZKX.SI    ZXY.SI
# Date
# 2025-08-25  12510000.0  32030400.0  153390.0  32500.0       NaN  466900.0
# 2025-08-26   2633600.0  37213200.0  293210.0      NaN  243800.0  100000.0
# 2025-08-27   3735000.0  24023870.0  168090.0  37200.0   43500.0   59300.0
# 2025-08-28   4401400.0  25496600.0  122400.0      NaN  135300.0       0.0
# 2025-08-29   2388700.0  16054600.0  100000.0      NaN   84400.0  205400.0
#
# [5 rows x 1437 columns]

# %%
data= filtered_df.T

# %%
data
# Out:
# Price       Close                                                             \
# Ticker     1A1.SI 1AZ.SI 1B1.SI 1D0.SI    1E3.SI 1F2.SI 1J4.SI 1J5.SI 1J7.SI
# Date
# 2025-08-25  0.171  0.265  0.330  0.355  0.233232  0.365   0.26  0.320    0.2
# 2025-08-26  0.182  0.275  0.330  0.360  0.233232  0.380   0.26  0.325    0.2
# 2025-08-27  0.245  0.275  0.330  0.360  0.228270  0.375   0.25  0.330    0.2
# 2025-08-28  0.180  0.275  0.325  0.360  0.230000  0.365   0.25  0.340    0.2
# 2025-08-29  0.180  0.280  0.330  0.365  0.255000  0.375   0.25  0.340    0.2
#
# Price              ...     Volume                                   \
# Ticker     1MZ.SI  ...     XZL.SI   Y03.SI      Y92.SI      YF8.SI
# Date               ...
# 2025-08-25  0.765  ...  1156600.0   2900.0  14131600.0  11404000.0
# 2025-08-26  0.730  ...   254000.0      0.0  26466700.0  13453700.0
# 2025-08-27  0.725  ...   180000.0  10000.0   9129400.0   6873100.0
# 2025-08-28  0.710  ...   315300.0      0.0  13305000.0   8090800.0
# 2025-08-29  0.710  ...   650000.0   4700.0   5714400.0  12083500.0
#
# Price
# Ticker          Z25.SI      Z74.SI    Z77.SI   ZB9.SI    ZKX.SI    ZXY.SI
# Date
# 2025-08-25  12510000.0  32030400.0  153390.0  32500.0       NaN  466900.0
# 2025-08-26   2633600.0  37213200.0  293210.0      NaN  243800.0  100000.0
# 2025-08-27   3735000.0  24023870.0  168090.0  37200.0   43500.0   59300.0
# 2025-08-28   4401400.0  25496600.0  122400.0      NaN  135300.0       0.0
# 2025-08-29   2388700.0  16054600.0  100000.0      NaN   84400.0  205400.0
#
# [5 rows x 1437 columns]

# %%
cols = list(filtered_df.T["Close"].columns)

# %%
cols
# Out:
# ['1A1.SI',
#  '1AZ.SI',
#  '1B1.SI',
#  '1D0.SI',
#  '1E3.SI',
#  '1F2.SI',
#  '1J4.SI',
#  '1J5.SI',
#  '1J7.SI',
#  '1MZ.SI',
#  '1R6.SI',
#  '40T.SI',
#  '41B.SI',
#  '41O.SI',
#  '42E.SI',
#  '42R.SI',
#  '500.SI',
#  '508.SI',
#  '533.SI',
#  '53W.SI',
#  '543.SI',
#  '544.SI',
#  '558.SI',
#  '564.SI',
#  '5CF.SI',
#  '5DD.SI',
#  '5DP.SI',
#  '5DS.SI',
#  '5E2.SI',
#  '5G3.SI',
#  '5GD.SI',
#  '5IC.SI',
#  '5JK.SI',
#  '5JS.SI',
#  '5MD.SI',
#  '5ML.SI',
#  '5MZ.SI',
#  '5SR.SI',
#  '5SY.SI',
#  '5TP.SI',
#  '5VJ.SI',
#  '5VS.SI',
#  '5WJ.SI',
#  '600.SI',
#  '8A8.SI',
#  '8AZ.SI',
#  '9A4U.SI',
#  '9CI.SI',
#  'A17U.SI',
#  'A7RU.SI',
#  'ACV.SI',
#  'ADN.SI',
#  'AGS.SI',
#  'AIY.SI',
#  'AJBU.SI',
#  'AP4.SI',
#  'AU8U.SI',
#  'AVX.SI',
#  'AW9U.SI',
#  'AWC.SI',
#  'AWG.SI',
#  'AWI.SI',
#  'AWK.SI',
#  'AWV.SI',
#  'AWX.SI',
#  'AWZ.SI',
#  'AYN.SI',
#  'B28.SI',
#  'B58.SI',
#  'B61.SI',
#  'B9S.SI',
#  'BAI.SI',
#  'BAZ.SI',
#  'BBP.SI',
#  'BBW.SI',
#  'BCY.SI',
#  'BDA.SI',
#  'BDR.SI',
#  'BEC.SI',
#  'BEI.SI',
#  'BEW.SI',
#  'BEZ.SI',
#  'BFK.SI',
#  'BFU.SI',
#  'BHU.SI',
#  'BIX.SI',
#  'BJZ.SI',
#  'BKA.SI',
#  'BKK.SI',
#  'BKX.SI',
#  'BLH.SI',
#  'BLS.SI',
#  'BMGU.SI',
#  'BN2.SI',
#  'BN4.SI',
#  'BNE.SI',
#  'BPF.SI',
#  'BQD.SI',
#  'BQF.SI',
#  'BQM.SI',
#  'BQP.SI',
#  'BS6.SI',
#  'BSL.SI',
#  'BTE.SI',
#  'BTG.SI',
#  'BTJ.SI',
#  'BTM.SI',
#  'BTP.SI',
#  'BTX.SI',
#  'BTY.SI',
#  'BUOU.SI',
#  'BVQ.SI',
#  'BWCU.SI',
#  'BWM.SI',
#  'C05.SI',
#  'C07.SI',
#  'C09.SI',
#  'C2PU.SI',
#  'C38U.SI',
#  'C41.SI',
#  'C52.SI',
#  'C6L.SI',
#  'C76.SI',
#  'CC3.SI',
#  'CHJ.SI',
#  'CHZ.SI',
#  'CJLU.SI',
#  'CJN.SI',
#  'CLN.SI',
#  'CMOU.SI',
#  'CRPU.SI',
#  'CY6U.SI',
#  'D01.SI',
#  'D05.SI',
#  'DCRU.SI',
#  'DHLU.SI',
#  'DM0.SI',
#  'E28.SI',
#  'E3B.SI',
#  'E5H.SI',
#  'EB5.SI',
#  'EH5.SI',
#  'EMI.SI',
#  'ER0.SI',
#  'F03.SI',
#  'F17.SI',
#  'F1E.SI',
#  'F34.SI',
#  'F99.SI',
#  'F9D.SI',
#  'G07.SI',
#  'G0I.SI',
#  'G13.SI',
#  'G20.SI',
#  'G50.SI',
#  'G92.SI',
#  'H02.SI',
#  'H07.SI',
#  'H12.SI',
#  'H13.SI',
#  'H15.SI',
#  'H18.SI',
#  'H22.SI',
#  'H30.SI',
#  'H78.SI',
#  'HKB.SI',
#  'HLS.SI',
#  'HMN.SI',
#  'HQU.SI',
#  'I06.SI',
#  'I07.SI',
#  'ITS.SI',
#  'J2T.SI',
#  'J36.SI',
#  'J69U.SI',
#  'J85.SI',
#  'JLB.SI',
#  'JYEU.SI',
#  'K03.SI',
#  'K29.SI',
#  'K6S.SI',
#  'K71U.SI',
#  'K75.SI',
#  'KYB.SI',
#  'L19.SI',
#  'LCC.SI',
#  'LJ3.SI',
#  'LMS.SI',
#  'LVR.SI',
#  'M01.SI',
#  'M04.SI',
#  'M05.SI',
#  'M14.SI',
#  'M1GU.SI',
#  'M44U.SI',
#  'ME8U.SI',
#  'MR7.SI',
#  'MV4.SI',
#  'MXNU.SI',
#  'MZH.SI',
#  'N02.SI',
#  'N08.SI',
#  'N0Z.SI',
#  'N2IU.SI',
#  'NC2.SI',
#  'NEX.SI',
#  'NIO.SI',
#  'NPW.SI',
#  'NS8U.SI',
#  'NTDU.SI',
#  'O10.SI',
#  'O39.SI',
#  'O5RU.SI',
#  'O6Z.SI',
#  'OAJ.SI',
#  'ODBU.SI',
#  'OTX.SI',
#  'OU8.SI',
#  'OV8.SI',
#  'OYY.SI',
#  'P15.SI',
#  'P34.SI',
#  'P40U.SI',
#  'P52.SI',
#  'P7VU.SI',
#  'P8A.SI',
#  'P8Z.SI',
#  'P9D.SI',
#  'PCT.SI',
#  'Q01.SI',
#  'Q0F.SI',
#  'Q5T.SI',
#  'QC7.SI',
#  'QES.SI',
#  'QNS.SI',
#  'RE4.SI',
#  'S07.SI',
#  'S08.SI',
#  'S19.SI',
#  'S20.SI',
#  'S23.SI',
#  'S29.SI',
#  'S2D.SI',
#  'S35.SI',
#  'S41.SI',
#  'S44.SI',
#  'S56.SI',
#  'S58.SI',
#  'S59.SI',
#  'S61.SI',
#  'S63.SI',
#  'S68.SI',
#  'S85.SI',
#  'SEB.SI',
#  'SET.SI',
#  'SO7.SI',
#  'STG.SI',
#  'T12.SI',
#  'T14.SI',
#  'T15.SI',
#  'T24.SI',
#  'T55.SI',
#  'T6I.SI',
#  'T82U.SI',
#  'TCU.SI',
#  'TQ5.SI',
#  'TS0U.SI',
#  'TSH.SI',
#  'U06.SI',
#  'U10.SI',
#  'U11.SI',
#  'U13.SI',
#  'U14.SI',
#  'U77.SI',
#  'U96.SI',
#  'U9E.SI',
#  'UD1U.SI',
#  'URR.SI',
#  'UZF.SI',
#  'V03.SI',
#  'V5Q.SI',
#  'VC2.SI',
#  'W05.SI',
#  'WJP.SI',
#  'WKS.SI',
#  'X5N.SI',
#  'XVG.SI',
#  'XWA.SI',
#  'XZL.SI',
#  'Y03.SI',
#  'Y92.SI',
#  'YF8.SI',
#  'YYN.SI',
#  'Z25.SI',
#  'Z74.SI',
#  'Z77.SI',
#  'ZB9.SI',
#  'ZKX.SI',
#  'ZXY.SI']

# %%
def check_trend(pct_series: pd.Series):
    # condition 1: 2 consecutive >= +1%
    cond1 = ((pct_series >= .5).astype(int)
        .rolling(2).sum() >= 2).any()

    # condition 2: 3 consecutive > 0
    cond2 = ((pct_series > 0).astype(int)
             .rolling(3).sum() >= 3).any()

    final_higher = close_series.iloc[-1] > close_series.iloc[-2]

    # return cond1, cond2
    return (cond1 and final_higher), (cond2 and final_higher)

# %%
for item in cols:
    # print(item)
    close_series = data["Close"][item]
    open_series = data["Open"][item]

    pct_change_open_close = ((close_series - open_series) / open_series) * 100
    # print(pct_change_open_close)
    close_close_pct = close_series.pct_change() * 100
    c1, c2 = check_trend(close_close_pct)

    if c1 or c2:
        print(item)
# Out:
# 1E3.SI
# 5WJ.SI
# AGS.SI
# AWX.SI
# AWZ.SI
# BEZ.SI
# BN4.SI
# BQF.SI
# C76.SI
# CHZ.SI
# D05.SI
# E28.SI
# HMN.SI
# I07.SI
# J36.SI
# J69U.SI
# K03.SI
# LCC.SI
# M44U.SI
# MXNU.SI
# N02.SI
# N2IU.SI
# ODBU.SI
# OYY.SI
# P8Z.SI
# P9D.SI
# Q5T.SI
# S35.SI
# S41.SI
# T15.SI
# T82U.SI
# C:\Users\john\AppData\Local\Temp\ipykernel_8836\2716322568.py:8: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   close_close_pct = close_series.pct_change() * 100

# %%
filtered_df = data[data[today] > 5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2025-08-27'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 filtered_df = data[data[today] > 5]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4106, in DataFrame.__getitem__(self, key)
#    4104 if is_single_key:
#    4105     if self.columns.nlevels > 1:
# -> 4106         return self._getitem_multilevel(key)
#    4107     indexer = self.columns.get_loc(key)
#    4108     if is_integer(indexer):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4164, in DataFrame._getitem_multilevel(self, key)
#    4162 def _getitem_multilevel(self, key):
#    4163     # self.columns is a MultiIndex
# -> 4164     loc = self.columns.get_loc(key)
#    4165     if isinstance(loc, (slice, np.ndarray)):
#    4166         new_columns = self.columns[loc]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:3059, in MultiIndex.get_loc(self, key)
#    3056     return mask
#    3058 if not isinstance(key, tuple):
# -> 3059     loc = self._get_level_indexer(key, level=0)
#    3060     return _maybe_to_slice(loc)
#    3062 keylen = len(key)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:3410, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3407         return slice(i, j, step)
#    3409 else:
# -> 3410     idx = self._get_loc_single_level_index(level_index, key)
#    3412     if level > 0 or self._lexsort_depth == 0:
#    3413         # Desired level is not sorted
#    3414         if isinstance(idx, slice):
#    3415             # test_get_loc_partial_timestamp_multiindex
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:2999, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2997     return -1
#    2998 else:
# -> 2999     return level_index.get_loc(key)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '2025-08-27'

# %%
dat = yf.download(['AAPL', 'GOOG', "MSFT"], period='5d')

print(dat)

# %%
close_df = dat["Close"]["AAPL"]

# %%
close_df

# %%
open_df = dat["Open"]["AAPL"]

# %%
open_df

# %%
print(dat.columns)

# %%
open_series = dat["Open"]["AAPL"]
close_series = dat["Close"]["AAPL"]

pct_change_open_close = ((close_series - open_series) / open_series) * 100
print(pct_change_open_close)
# Out:
# Date
# 2025-08-25    0.300251
# 2025-08-26    1.075507
# 2025-08-27    0.822363
# 2025-08-28    0.753830
# 2025-08-29   -0.159131
# Name: AAPL, dtype: float64

# %%
def check_trend(pct_series: pd.Series):
    # condition 1: 2 consecutive >= +1%
    cond1 = ((pct_series >= 1).astype(int)
             .rolling(2).sum() >= 2).any()

    # condition 2: 3 consecutive > 0
    cond2 = ((pct_series > 0).astype(int)
             .rolling(3).sum() >= 3).any()

    return cond1, cond2

# %%
pct_change_open_close = ((close_series - open_series) / open_series) * 100
c1, c2 = check_trend(pct_change_open_close)

print("2 consecutive >= +1%:", c1)
print("3 consecutive > 0:", c2)
# Out:
# 2 consecutive >= +1%: False
# 3 consecutive > 0: True
